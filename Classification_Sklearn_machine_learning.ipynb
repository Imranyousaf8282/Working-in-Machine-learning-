# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
titanic = pd.read_csv('kashti.csv')
titanic
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
titanic.rename({"Unnamed: 0":"passengerId"},axis=1,inplace=True)

# %%
titanic
# Out:
#      passengerId  survived  pclass     sex    age  sibsp  parch      fare  \
# 0              0         0       3    male  22.00      1      0    7.2500
# 1              1         1       1  female  38.00      1      0   71.2833
# 2              2         1       3  female  26.00      0      0    7.9250
# 3              3         1       1  female  35.00      1      0   53.1000
# 4              4         0       3    male  35.00      0      0    8.0500
# 5              5         0       3    male    NaN      0      0    8.4583
# 6              6         0       1    male  54.00      0      0   51.8625
# 7              7         0       3    male   2.00      3      1   21.0750
# 8              8         1       3  female  27.00      0      2   11.1333
# 9              9         1       2  female  14.00      1      0   30.0708
# 10            10         1       3  female   4.00      1      1   16.7000
# 11            11         1       1  female  58.00      0      0   26.5500
# ...

# %%
titanic.drop("alone",axis=1,inplace=True)
titanic.drop("class",axis=1,inplace=True)
titanic.drop("who",axis=1,inplace=True)
titanic.drop("adult_male",axis=1,inplace=True)
titanic.drop("deck",axis=1,inplace=True)
titanic.drop("embark_town",axis=1,inplace=True)
titanic.drop("alive",axis=1,inplace=True)

# %%
titanic
# Out:
#      passengerId  survived  pclass     sex    age  sibsp  parch      fare  \
# 0              0         0       3    male  22.00      1      0    7.2500
# 1              1         1       1  female  38.00      1      0   71.2833
# 2              2         1       3  female  26.00      0      0    7.9250
# 3              3         1       1  female  35.00      1      0   53.1000
# 4              4         0       3    male  35.00      0      0    8.0500
# 5              5         0       3    male    NaN      0      0    8.4583
# 6              6         0       1    male  54.00      0      0   51.8625
# 7              7         0       3    male   2.00      3      1   21.0750
# 8              8         1       3  female  27.00      0      2   11.1333
# 9              9         1       2  female  14.00      1      0   30.0708
# 10            10         1       3  female   4.00      1      1   16.7000
# 11            11         1       1  female  58.00      0      0   26.5500
# ...

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.select_dtypes(["O"]).columns
# Out:
# Index(['sex', 'embarked'], dtype='object')

# %%
sex = pd.get_dummies(titanic['sex'],drop_first=True)
embarked = pd.get_dummies(titanic['embarked'], drop_first=True)

# %%
titanic.head()
# Out:
#    passengerId  survived  pclass     sex   age  sibsp  parch     fare embarked
# 0            0         0       3    male  22.0      1      0   7.2500        S
# 1            1         1       1  female  38.0      1      0  71.2833        C
# 2            2         1       3  female  26.0      0      0   7.9250        S
# 3            3         1       1  female  35.0      1      0  53.1000        S
# 4            4         0       3    male  35.0      0      0   8.0500        S

# %%
titanic = pd.concat([titanic,sex,embarked],axis=1)

# %%
titanic.head()
# Out:
#    passengerId  survived  pclass     sex   age  sibsp  parch     fare  \
# 0            0         0       3    male  22.0      1      0   7.2500
# 1            1         1       1  female  38.0      1      0  71.2833
# 2            2         1       3  female  26.0      0      0   7.9250
# 3            3         1       1  female  35.0      1      0  53.1000
# 4            4         0       3    male  35.0      0      0   8.0500
#
#   embarked   male      Q      S
# 0        S   True  False   True
# 1        C  False  False  False
# 2        S  False  False   True
# 3        S  False  False   True
# 4        S   True  False   True

# %%
titanic.drop(['sex','embarked'],axis=1,inplace=True)

# %%
titanic
# Out:
#      passengerId  survived  pclass    age  sibsp  parch      fare   male  \
# 0              0         0       3  22.00      1      0    7.2500   True
# 1              1         1       1  38.00      1      0   71.2833  False
# 2              2         1       3  26.00      0      0    7.9250  False
# 3              3         1       1  35.00      1      0   53.1000  False
# 4              4         0       3  35.00      0      0    8.0500   True
# 5              5         0       3    NaN      0      0    8.4583   True
# 6              6         0       1  54.00      0      0   51.8625   True
# 7              7         0       3   2.00      3      1   21.0750   True
# 8              8         1       3  27.00      0      2   11.1333  False
# 9              9         1       2  14.00      1      0   30.0708  False
# 10            10         1       3   4.00      1      1   16.7000  False
# 11            11         1       1  58.00      0      0   26.5500  False
# ...

# %%
titanic.select_dtypes(["O"]).columns
# Out:
# Index([], dtype='object')

# %%
titanic['age'].fillna(titanic['age'].mode()[0], inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11412\2286211400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].fillna(titanic['age'].mode()[0], inplace=True)

# %%
titanic
# Out:
#      passengerId  survived  pclass    age  sibsp  parch      fare   male  \
# 0              0         0       3  22.00      1      0    7.2500   True
# 1              1         1       1  38.00      1      0   71.2833  False
# 2              2         1       3  26.00      0      0    7.9250  False
# 3              3         1       1  35.00      1      0   53.1000  False
# 4              4         0       3  35.00      0      0    8.0500   True
# 5              5         0       3  24.00      0      0    8.4583   True
# 6              6         0       1  54.00      0      0   51.8625   True
# 7              7         0       3   2.00      3      1   21.0750   True
# 8              8         1       3  27.00      0      2   11.1333  False
# 9              9         1       2  14.00      1      0   30.0708  False
# 10            10         1       3   4.00      1      1   16.7000  False
# 11            11         1       1  58.00      0      0   26.5500  False
# ...

# %%
titanic.describe()
# Out:
#        passengerId    survived      pclass         age       sibsp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    445.000000    0.383838    2.308642   28.566970    0.523008
# std     257.353842    0.486592    0.836071   13.199572    1.102743
# min       0.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.500000    0.000000    2.000000   22.000000    0.000000
# 50%     445.000000    0.000000    3.000000   24.000000    0.000000
# 75%     667.500000    1.000000    3.000000   35.000000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    8.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerId  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   male         891 non-null    bool
#  8   Q            891 non-null    bool
#  9   S            891 non-null    bool
# dtypes: bool(3), float64(2), int64(5)
# memory usage: 51.5 KB

# %%
predictors = ["passengerId","pclass","age","sibsp","parch","fare","male","Q","S"]

# %%
X = titanic[predictors]
y = titanic['survived']

# %% [markdown]
# ### model training

# %%
from sklearn.model_selection import train_test_split
X_trian,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=101)

# %% [markdown]
# ## Logistic regresssion

# %%
from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression()

# %%
lreg.fit(X_trian,y_train)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lreg
# Out:
# LogisticRegression()

# %%
prediction_train = lreg.predict(X_trian)

# %%
prediction_test = lreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,recall_score,precision_score

# %%
acc_score_train = accuracy_score(y_train,prediction_train)
acc_score_train*100
# Out:
# 78.51123595505618

# %%
acc_score_test = accuracy_score(y_test,prediction_test)
acc_score_test*100
# Out:
# 78.2122905027933

# %%
class_report_train = classification_report(y_train,prediction_train)
print(class_report_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       450
#            1       0.72      0.68      0.70       262
#
#     accuracy                           0.79       712
#    macro avg       0.77      0.76      0.77       712
# weighted avg       0.78      0.79      0.78       712

# %%
class_report_test = classification_report(y_test,prediction_test)
print(class_report_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        99
#            1       0.81      0.68      0.73        80
#
#     accuracy                           0.78       179
#    macro avg       0.79      0.77      0.77       179
# weighted avg       0.78      0.78      0.78       179

# %%
cm_train = confusion_matrix(y_train,prediction_train)
sns.heatmap(cm_train,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
cm_test = confusion_matrix(y_test,prediction_test)
sns.heatmap(cm_test,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
recall_score_train = recall_score(y_train,prediction_train)
recall_score_train
# Out:
# 0.683206106870229

# %%
recall_score_test = recall_score(y_test,prediction_test)
recall_score_test
# Out:
# 0.675

# %%
precision_score(y_train,prediction_train)
# Out:
# 0.7188755020080321

# %%
precision_score(y_test,prediction_test)
# Out:
# 0.8059701492537313

# %% [markdown]
# * Precision_score = Tp(Tp+Fp)
# * Recall_score = Tp(Tp+FN)
# * F1_score = (precision_ppv*value + precision_ppn*value)/total_value

# %% [markdown]
# # Random Forest Classifictaion

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_trian,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction_train_rfc = rfc.predict(X_trian)

# %%
prediction_test_rfc = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix

# %%
acc_score_rfc = accuracy_score(y_train,prediction_train_rfc)
acc_score_rfc*100
# Out:
# 100.0

# %%
acc_score_rfc = accuracy_score(y_test,prediction_test_rfc)
acc_score_rfc*100
# Out:
# 83.79888268156425

# %%
recall_score_rfc = recall_score(y_test,prediction_test_rfc)
recall_score_rfc
# Out:
# 0.725

# %%
cm_rfc = confusion_matrix(y_test,prediction_test_rfc)
sns.heatmap(cm_rfc,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_trian,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction_train_dtc = dtc.predict(X_trian)

# %%
prediction_test_dtc = dtc.predict(X_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score,f1_score

# %%
acc_score_dtc = accuracy_score(y_train,prediction_train_dtc)
acc_score_dtc*100
# Out:
# 100.0

# %%
acc_score_dtc = accuracy_score(y_test,prediction_test_dtc)
acc_score_dtc*100
# Out:
# 74.30167597765363

# %%
class_report_train = classification_report(y_train,prediction_train_dtc)
print(class_report_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       450
#            1       1.00      1.00      1.00       262
#
#     accuracy                           1.00       712
#    macro avg       1.00      1.00      1.00       712
# weighted avg       1.00      1.00      1.00       712

# %%
class_report_test = classification_report(y_test,prediction_test_dtc)
print(class_report_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77        99
#            1       0.72      0.70      0.71        80
#
#     accuracy                           0.74       179
#    macro avg       0.74      0.74      0.74       179
# weighted avg       0.74      0.74      0.74       179

# %%
recall_score(y_train,prediction_train_dtc)
# Out:
# 1.0

# %%
recall_score(y_test,prediction_test_dtc)
# Out:
# 0.7

# %%
precision_score(y_train,prediction_train_dtc)
# Out:
# 1.0

# %%
precision_score(y_test,prediction_test_dtc)
# Out:
# 0.717948717948718

# %% [markdown]
# ## Gradient Bossting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
Grad_Boosting = GradientBoostingClassifier()
Grad_Boosting.fit(X_trian,y_train)
# Out:
# GradientBoostingClassifier()

# %%
prediction_train_gbc = Grad_Boosting.predict(X_trian)

# %%
prediction_test_gbc = Grad_Boosting.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,recall_score,precision_score,f1_score,confusion_matrix

# %%
acc_score_gbc = accuracy_score(y_test,prediction_test_gbc)
acc_score_gbc*100
# Out:
# 83.24022346368714

# %%
recall_score(y_test,prediction_test_gbc)
# Out:
# 0.6875

# %%
precision_score(y_test,prediction_test_gbc)
# Out:
# 0.9166666666666666

# %%
print(classification_report(y_test,prediction_test_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86        99
#            1       0.92      0.69      0.79        80
#
#     accuracy                           0.83       179
#    macro avg       0.85      0.82      0.82       179
# weighted avg       0.85      0.83      0.83       179

# %%
cm_gbc = confusion_matrix(y_test,prediction_test_gbc)
sns.heatmap(cm_gbc,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * All model score

# %%
model_score ={
    "LogisticRegression":78.21,
    "Decision Tree ":74.30,
    "RandomForest Classification":83.79,
    "Gradient Bossting Classifier":83.20
}
model_score
# Out:
# {'LogisticRegression': 78.21,
#  'Decision Tree ': 74.3,
#  'RandomForest Classification': 83.79,
#  'Gradient Bossting Classifier': 83.2}
