# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
liver_crisis = pd.read_csv('liver_cirrhosis.csv')
liver_crisis
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %%
liver_crisis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         25000 non-null  int64
#  1   Status         25000 non-null  object
#  2   Drug           25000 non-null  object
#  3   Age            25000 non-null  int64
#  4   Sex            25000 non-null  object
#  5   Ascites        25000 non-null  object
#  6   Hepatomegaly   25000 non-null  object
#  7   Spiders        25000 non-null  object
#  8   Edema          25000 non-null  object
#  9   Bilirubin      25000 non-null  float64
#  10  Cholesterol    25000 non-null  float64
#  11  Albumin        25000 non-null  float64
#  12  Copper         25000 non-null  float64
#  13  Alk_Phos       25000 non-null  float64
#  14  SGOT           25000 non-null  float64
#  15  Tryglicerides  25000 non-null  float64
#  16  Platelets      25000 non-null  float64
# ...

# %%
numeric_data = liver_crisis.select_dtypes(np.number)
numeric_data
# Out:
#        N_Days    Age  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  \
# 0        2221  18499        0.5   149.000000     4.04   227.0     598.0
# 1        1230  19724        0.5   219.000000     3.93    22.0     663.0
# 2        4184  11839        0.5   320.000000     3.54    51.0    1243.0
# 3        2090  16467        0.7   255.000000     3.74    23.0    1024.0
# 4        2105  21699        1.9   486.000000     3.54    74.0    1052.0
# ...       ...    ...        ...          ...      ...     ...       ...
# 24995    3584  23612        0.8   231.000000     3.87   173.0    9009.8
# 24996    3584  23612        0.8   231.000000     3.87   173.0    9009.8
# 24997     971  16736        5.1   369.510563     3.23    18.0     790.0
# 24998    3707  16990        0.8   315.000000     4.24    13.0    1637.0
# 24999    3707  16990        0.8   315.000000     4.24    13.0    1637.0
#
#          SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
corr = numeric_data.corr()
corr
# Out:
#                  N_Days       Age  Bilirubin  Cholesterol   Albumin    Copper  \
# N_Days         1.000000 -0.060569  -0.394799    -0.123461  0.368851 -0.281349
# Age           -0.060569  1.000000   0.006081    -0.035932 -0.108807  0.006670
# Bilirubin     -0.394799  0.006081   1.000000     0.339106 -0.283105  0.432199
# Cholesterol   -0.123461 -0.035932   0.339106     1.000000 -0.066418  0.129223
# Albumin        0.368851 -0.108807  -0.283105    -0.066418  1.000000 -0.179171
# Copper        -0.281349  0.006670   0.432199     0.129223 -0.179171  1.000000
# Alk_Phos       0.147792  0.029575   0.112972     0.116131 -0.125686  0.200772
# SGOT          -0.220532  0.011165   0.368024     0.322450 -0.162569  0.281353
# Tryglicerides -0.147606  0.030719   0.379776     0.248305 -0.111661  0.253358
# Platelets      0.115908 -0.123611  -0.095162     0.008835  0.118662 -0.074730
# Prothrombin   -0.149960  0.042134   0.254145     0.006194 -0.215859  0.141349
# ...

# %%
corr['Stage']
# Out:
# N_Days          -0.309484
# Age              0.165988
# Bilirubin        0.168006
# Cholesterol      0.025415
# Albumin         -0.231631
# Copper           0.131763
# Alk_Phos         0.084407
# SGOT             0.175301
# Tryglicerides    0.079228
# Platelets       -0.250058
# Prothrombin      0.288107
# Stage            1.000000
# Name: Stage, dtype: float64

# %%
predictor = ['Age','Bilirubin','Copper','SGOT','Prothrombin']
predictor
# Out:
# ['Age', 'Bilirubin', 'Copper', 'SGOT', 'Prothrombin']

# %%
cat_data = liver_crisis.select_dtypes('O')
cat_data
# Out:
#       Status             Drug Sex Ascites Hepatomegaly Spiders Edema
# 0          C          Placebo   F       N            Y       N     N
# 1          C          Placebo   M       Y            N       Y     N
# 2          C          Placebo   F       N            N       N     N
# 3          D          Placebo   F       N            N       N     N
# 4          D          Placebo   F       N            Y       N     N
# ...      ...              ...  ..     ...          ...     ...   ...
# 24995      D  D-penicillamine   F       N            N       N     N
# 24996      D  D-penicillamine   F       N            N       N     N
# 24997      D  D-penicillamine   F       N            Y       Y     Y
# 24998      C  D-penicillamine   F       N            Y       N     N
# 24999      C  D-penicillamine   F       N            Y       N     N
#
# [25000 rows x 7 columns]

# %%
liver_crisis.boxplot("Stage",by='Status')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Status'>

# %%
liver_crisis.boxplot("Stage",by='Drug')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Drug'>

# %%
liver_crisis.boxplot("Stage",by='Sex')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Sex'>

# %%
liver_crisis.boxplot("Stage",by='Ascites')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Ascites'>

# %%
liver_crisis.boxplot("Stage",by='Hepatomegaly')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Hepatomegaly'>

# %%
liver_crisis.boxplot("Stage",by='Spiders')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Spiders'>

# %%
liver_crisis.boxplot("Stage",by='Edema')
# Out:
# <Axes: title={'center': 'Stage'}, xlabel='Edema'>

# %%
liver_crisis['Status'] = liver_crisis['Status'] == "C"

# %%
liver_crisis
# Out:
#        N_Days  Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0        2221    True          Placebo  18499   F       N            Y
# 1        1230    True          Placebo  19724   M       Y            N
# 2        4184    True          Placebo  11839   F       N            N
# 3        2090   False          Placebo  16467   F       N            N
# 4        2105   False          Placebo  21699   F       N            Y
# ...       ...     ...              ...    ...  ..     ...          ...
# 24995    3584   False  D-penicillamine  23612   F       N            N
# 24996    3584   False  D-penicillamine  23612   F       N            N
# 24997     971   False  D-penicillamine  16736   F       N            Y
# 24998    3707    True  D-penicillamine  16990   F       N            Y
# 24999    3707    True  D-penicillamine  16990   F       N            Y
#
#       Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  \
# ...

# %%
liver_crisis['Hepatomegaly'] = liver_crisis['Hepatomegaly'] == 'Y'

# %%
df['Sex'] = df['Sex'].replace({'F': 1, 'M': 0})
df['Drug'] = df['Drug'].replace({'Placebo': 1, 'D-penicillamine': 0})
df['Ascites'] = df['Ascites'].replace({'Y': 1, 'N': 0})
df['Hepatomegaly'] = df['Hepatomegaly'].replace({'Y': 1, 'N': 0})
df['Spiders'] = df['Spiders'].replace({'Y': 1, 'N': 0})
df['Edema'] = df['Edema'].replace({'Y': 1, 'N': 0,"S":2})
df["Status"]= df["Status"].replace({"C":0,"D":1,"CL":2})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['Sex'] = df['Sex'].replace({'F': 1, 'M': 0})
#       2 df['Drug'] = df['Drug'].replace({'Placebo': 1, 'D-penicillamine': 0})
#       3 df['Ascites'] = df['Ascites'].replace({'Y': 1, 'N': 0})
#
# NameError: name 'df' is not defined
