# %% [markdown]
# ### Import labraries and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
cancer_data = pd.read_csv("Breast_Cancer.csv")
cancer_data
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
cancer_data
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# 5      51  White        Single        T1      N1       IIA
# 6      51  White        Married       T1      N1       IIA
# 7      40  White        Married       T2      N1       IIB
# 8      40  White       Divorced       T4      N3      IIIC
# 9      69  White        Married       T4      N3      IIIC
# 10     68  White        Widowed       T1      N1       IIA
# 11     46  White        Married       T3      N1      IIIA
# 12     65  White        Married       T2      N1       IIB
# 13     48  White        Married       T1      N2      IIIA
# 14     62  White       Divorced       T2      N3      IIIC
# ...

# %%
cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %% [markdown]
# ### **Feature Enginnering**

# %%
cancer_data['Progesterone Status']=='Positive'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11      False
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19      False
# 20       True
# 21       True
# 22       True
# 23      False
# 24       True
# 25       True
# 26       True
# 27       True
# 28      False
# 29       True
# 30       True
# 31       True
# 32       True
# 33      False
# 34       True
# 35       True
# 36      False
# 37       True
# 38       True
# 39       True
# 40       True
# 41       True
# 42      False
# 43      False
# 44       True
# 45       True
# 46      False
# 47       True
# 48       True
# 49       True
# 50       True
# 51      False
# 52      False
# 53      False
# 54      False
# 55       True
# 56       True
# 57      False
# 58       True
# 59       True
# 60      False
# 61      False
# ...

# %%
cancer_data['Progesterone Status'] = cancer_data['Progesterone Status']=='Positive'

# %%
cancer_data['A Stage']= cancer_data['A Stage'] =='Regional'

# %%
cancer_data['Estrogen Status']= cancer_data['Estrogen Status']=='Positive'

# %%
cancer_data['Status'] = cancer_data['Status'] =='Alive'

# %%
cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   bool
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   bool
#  11  Progesterone Status     4024 non-null   bool
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
cancer_data.select_dtypes(["O"]).columns
# Out:
# Index(['Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade'],
#       dtype='object')

# %%
cancer_data['Race'].value_counts()
# Out:
# Race
# White    3413
# Other     320
# Black     291
# Name: count, dtype: int64

# %%
cancer_data['Race'].unique()
# Out:
# array(['White', 'Black', 'Other'], dtype=object)

# %%
cancer_data['Race'] = cancer_data['Race'].replace(['White', 'Black', 'Other'],[1,0,2])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\2507726912.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['Race'] = cancer_data['Race'].replace(['White', 'Black', 'Other'],[1,0,2])

# %%
cancer_data['Marital Status'].unique()
# Out:
# array(['Married', 'Divorced', 'Single ', 'Widowed', 'Separated'],
#       dtype=object)

# %%
cancer_data['Marital Status']=cancer_data['Marital Status'].replace(['Married', 'Divorced', 'Single ', 'Widowed', 'Separated'],[1,0,2,3,4])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\2737420055.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['Marital Status']=cancer_data['Marital Status'].replace(['Married', 'Divorced', 'Single ', 'Widowed', 'Separated'],[1,0,2,3,4])

# %%
cancer_data['T Stage '].unique()
# Out:
# array(['T1', 'T2', 'T3', 'T4'], dtype=object)

# %%
cancer_data['T Stage ']=cancer_data['T Stage '].replace(['T1', 'T2', 'T3', 'T4'],[1,2,3,4])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\1850867202.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['T Stage ']=cancer_data['T Stage '].replace(['T1', 'T2', 'T3', 'T4'],[1,2,3,4])

# %%
cancer_data['N Stage'].unique()
# Out:
# array(['N1', 'N2', 'N3'], dtype=object)

# %%
cancer_data['N Stage']=cancer_data['N Stage'].replace(['N1', 'N2', 'N3'],[1,2,3])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\2148259387.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['N Stage']=cancer_data['N Stage'].replace(['N1', 'N2', 'N3'],[1,2,3])

# %%
cancer_data['6th Stage'].unique()
# Out:
# array(['IIA', 'IIIA', 'IIIC', 'IIB', 'IIIB'], dtype=object)

# %%
cancer_data['6th Stage']=cancer_data['6th Stage'].replace(['IIA', 'IIIA', 'IIIC', 'IIB', 'IIIB'],[1,2,3,4,5])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\2740224214.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['6th Stage']=cancer_data['6th Stage'].replace(['IIA', 'IIIA', 'IIIC', 'IIB', 'IIIB'],[1,2,3,4,5])

# %%
cancer_data['Grade'].unique()
# Out:
# array(['3', '2', '1', ' anaplastic; Grade IV'], dtype=object)

# %%
cancer_data['Grade']=cancer_data['Grade'].replace(['3', '2', '1', ' anaplastic; Grade IV'],[1,2,3,4])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\1947426188.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['Grade']=cancer_data['Grade'].replace(['3', '2', '1', ' anaplastic; Grade IV'],[1,2,3,4])

# %%
cancer_data['differentiate'].unique()
# Out:
# array(['Poorly differentiated', 'Moderately differentiated',
#        'Well differentiated', 'Undifferentiated'], dtype=object)

# %%
cancer_data['differentiate']=cancer_data['differentiate'].replace(['Poorly differentiated', 'Moderately differentiated',
       'Well differentiated', 'Undifferentiated'],[1,2,3,0])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12156\2270946194.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cancer_data['differentiate']=cancer_data['differentiate'].replace(['Poorly differentiated', 'Moderately differentiated',

# %%
cancer_data.head()
# Out:
#    Age  Race  Marital Status  T Stage   N Stage  6th Stage  differentiate  \
# 0   68     1               1         1        1          1              1
# 1   50     1               1         2        2          2              2
# 2   58     1               0         3        3          3              2
# 3   58     1               1         1        1          1              1
# 4   47     1               1         2        1          4              1
#
#    Grade  A Stage  Tumor Size  Estrogen Status  Progesterone Status  \
# 0      1     True           4             True                 True
# 1      2     True          35             True                 True
# 2      2     True          63             True                 True
# 3      1     True          18             True                 True
# 4      1     True          41             True                 True
#
#    Regional Node Examined  Reginol Node Positive  Survival Months  Status
# ...

# %%
cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   int64
#  2   Marital Status          4024 non-null   int64
#  3   T Stage                 4024 non-null   int64
#  4   N Stage                 4024 non-null   int64
#  5   6th Stage               4024 non-null   int64
#  6   differentiate           4024 non-null   int64
#  7   Grade                   4024 non-null   int64
#  8   A Stage                 4024 non-null   bool
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   bool
#  11  Progesterone Status     4024 non-null   bool
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
cancer_data.corr()
# Out:
#                              Age      Race  Marital Status  T Stage   \
# Age                     1.000000 -0.029053        0.047754 -0.066914
# Race                   -0.029053  1.000000       -0.081868  0.006868
# Marital Status          0.047754 -0.081868        1.000000  0.001697
# T Stage                -0.066914  0.006868        0.001697  1.000000
# N Stage                 0.002883 -0.018134        0.017606  0.277015
# 6th Stage              -0.044969  0.001161       -0.006043  0.563704
# differentiate           0.099294  0.045346        0.005927 -0.131470
# Grade                   0.093216  0.032592        0.017188 -0.110220
# A Stage                 0.020860  0.007097       -0.000480 -0.221124
# Tumor Size             -0.077215  0.004629        0.001123  0.809176
# Estrogen Status         0.059787  0.020274       -0.028790 -0.060954
# Progesterone Status    -0.021269  0.018582       -0.025699 -0.057633
# Regional Node Examined -0.033345  0.009975       -0.002555  0.114102
# ...

# %%
X = cancer_data.drop("Status",axis=1)
y = cancer_data["Status"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   int64
#  2   Marital Status          4024 non-null   int64
#  3   T Stage                 4024 non-null   int64
#  4   N Stage                 4024 non-null   int64
#  5   6th Stage               4024 non-null   int64
#  6   differentiate           4024 non-null   int64
#  7   Grade                   4024 non-null   int64
#  8   A Stage                 4024 non-null   bool
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   bool
#  11  Progesterone Status     4024 non-null   bool
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %% [markdown]
# ### Training of model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=101)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
L_regression = LogisticRegression()

# %%
L_regression.fit(X_train,y_train)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction_train = L_regression.predict(X_train)

# %%
prediction_test = L_regression.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,precision_score,recall_score

# %%
accuracy_score(y_train,prediction_train)
# Out:
# 0.8934451693072383

# %%
accu_score = accuracy_score(y_test,prediction_test)
accu_score*100
# Out:
# 89.56521739130436

# %%
print(classification_report(y_test,prediction_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.81      0.41      0.55       123
#         True       0.90      0.98      0.94       682
#
#     accuracy                           0.90       805
#    macro avg       0.86      0.70      0.74       805
# weighted avg       0.89      0.90      0.88       805

# %%
preci_score = precision_score(y_test,prediction_test)
preci_score
# Out:
# 0.9029649595687331

# %%
recal_score = recall_score(y_test,prediction_test)
recal_score
# Out:
# 0.9824046920821115

# %%
cm = confusion_matrix(y_test,prediction_test)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <Axes: >

# %%
precision = 670/(670+72)
precision
# Out:
# 0.9029649595687331

# %%
recall = 670/(670+12)
recall
# Out:
# 0.9824046920821115

# %%
accuracy = (670+51)/(51+72+12+670)
accuracy*100
# Out:
# 89.56521739130436

# %% [markdown]
# ### Decision_Tree_Classification

# %%
from sklearn.tree import DecisionTreeClassifier
Dec_tre_Class = DecisionTreeClassifier()
Dec_tre_Class.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction_train = Dec_tre_Class.predict(X_train)
prediction_test = Dec_tre_Class.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score

# %%
accu_score_dtc = accuracy_score(y_test,prediction_test)
accu_score_dtc
# Out:
# 0.8472049689440994

# %%
preci_score_dtc = precision_score(y_test,prediction_test)
preci_score_dtc
# Out:
# 0.9092240117130308

# %%
cm_dtc = confusion_matrix(y_test,prediction_test)
sns.heatmap(cm_dtc,annot=True,fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### Gradient Bossting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
Grad_Boss_Class = GradientBoostingClassifier()
Grad_Boss_Class.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
prediction_train = Grad_Boss_Class.predict(X_train)
prediction_test = Grad_Boss_Class.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score

# %%
accu_score_gbc = accuracy_score(y_test,prediction_test)
accu_score_gbc
# Out:
# 0.9043478260869565

# %%
preci_score_gbc = precision_score(y_test,prediction_test)
preci_score_gbc
# Out:
# 0.9183955739972337

# %%
recal_score_gbc = recall_score(y_test,prediction_test)
recal_score_gbc
# Out:
# 0.9736070381231672

# %%
cm_gbc = confusion_matrix(y_test,prediction_test)
sns.heatmap(cm_gbc,annot=True,fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### All model score

# %%
model_score={
    "Logistic_regression":89.56521739130436,
    "Decision_tree":84.72049689440994,
    "Gradient_Boosting_Class":90.43478260869565
    
}
model_score
# Out:
# {'Logistic_regression': 89.56521739130436,
#  'Decision_tree': 84.72049689440993,
#  'Gradient_Boosting_Class': 90.43478260869566}
